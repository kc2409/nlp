# %%
# !pip install textsearch
# Out:
# Requirement already satisfied: textsearch in e:\anaconda new\lib\site-packages (0.0.21)
# Requirement already satisfied: pyahocorasick in e:\anaconda new\lib\site-packages (from textsearch) (1.4.4)
# Requirement already satisfied: anyascii in e:\anaconda new\lib\site-packages (from textsearch) (0.3.1)
# WARNING: You are using pip version 21.3; however, version 22.1 is available.
# You should consider upgrading via the 'E:\anaconda new\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install contractions
# Out:
# Requirement already satisfied: contractions in e:\anaconda new\lib\site-packages (0.1.72)
# Requirement already satisfied: textsearch>=0.0.21 in e:\anaconda new\lib\site-packages (from contractions) (0.0.21)
# Requirement already satisfied: anyascii in e:\anaconda new\lib\site-packages (from textsearch>=0.0.21->contractions) (0.3.1)
# Requirement already satisfied: pyahocorasick in e:\anaconda new\lib\site-packages (from textsearch>=0.0.21->contractions) (1.4.4)
# WARNING: You are using pip version 21.3; however, version 22.1 is available.
# You should consider upgrading via the 'E:\anaconda new\python.exe -m pip install --upgrade pip' command.

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pandas as pd
df=pd.read_csv('movies_metadata.csv')
df
# Out:
# E:\anaconda new\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45461                fa                      رگ خواب
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview  ... release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1      When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2      A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3      Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4      Just when George Banks has recovered from his ...  ...   1995-02-10
# ...                                                  ...  ...          ...
# 45461        Rising and falling between a man and woman.  ...          NaN
# 45462  An artist struggles to finish his work while a...  ...   2011-11-17
# 45463  When one of her hits goes wrong, a professiona...  ...   2003-08-01
# 45464  In a small town live two brothers, one a minis...  ...   1917-10-21
# 45465  50 years after decriminalisation of homosexual...  ...   2017-06-09
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45461          0.0    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462          0.0   360.0                  [{'iso_639_1': 'tl', 'name': ''}]
# 45463          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45464          0.0    87.0                                                 []
# 45465          0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45461  Released         Rising and falling between a man and woman
# 45462  Released                                                NaN
# 45463  Released                             A deadly game of wits.
# 45464  Released                                                NaN
# 45465  Released                                                NaN
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45461                       Subdue  False          4.0        1.0
# 45462          Century of Birthing  False          9.0        3.0
# 45463                     Betrayal  False          3.8        6.0
# 45464             Satan Triumphant  False          0.0        0.0
# 45465                     Queerama  False          0.0        0.0
#
# [45466 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
#  14  release_date           45379 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45460 non-null  object
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB

# %%
df.isnull()
# Out:
#        adult  belongs_to_collection  budget  genres  homepage     id  imdb_id  \
# 0      False                  False   False   False     False  False    False
# 1      False                   True   False   False      True  False    False
# 2      False                  False   False   False      True  False    False
# 3      False                   True   False   False      True  False    False
# 4      False                  False   False   False      True  False    False
# ...      ...                    ...     ...     ...       ...    ...      ...
# 45461  False                   True   False   False     False  False    False
# 45462  False                   True   False   False      True  False    False
# 45463  False                   True   False   False      True  False    False
# 45464  False                   True   False   False      True  False    False
# 45465  False                   True   False   False      True  False    False
#
#        original_language  original_title  overview  ...  release_date  \
# 0                  False           False     False  ...         False
# 1                  False           False     False  ...         False
# 2                  False           False     False  ...         False
# 3                  False           False     False  ...         False
# 4                  False           False     False  ...         False
# ...                  ...             ...       ...  ...           ...
# 45461              False           False     False  ...          True
# 45462              False           False     False  ...         False
# 45463              False           False     False  ...         False
# 45464              False           False     False  ...         False
# 45465              False           False     False  ...         False
#
#        revenue  runtime  spoken_languages  status  tagline  title  video  \
# 0        False    False             False   False     True  False  False
# 1        False    False             False   False    False  False  False
# 2        False    False             False   False    False  False  False
# 3        False    False             False   False    False  False  False
# 4        False    False             False   False    False  False  False
# ...        ...      ...               ...     ...      ...    ...    ...
# 45461    False    False             False   False    False  False  False
# 45462    False    False             False   False     True  False  False
# 45463    False    False             False   False    False  False  False
# 45464    False    False             False   False     True  False  False
# 45465    False    False             False   False     True  False  False
#
#        vote_average  vote_count
# 0             False       False
# 1             False       False
# 2             False       False
# 3             False       False
# 4             False       False
# ...             ...         ...
# 45461         False       False
# 45462         False       False
# 45463         False       False
# 45464         False       False
# 45465         False       False
#
# [45466 rows x 24 columns]

# %%
df=df.drop(['adult','belongs_to_collection','imdb_id','poster_path'],axis=1)

# %%
df=df.dropna()
df
# Out:
#          budget                                             genres  \
# 9      58000000  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 24      3600000  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 46     33000000  [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...
# 49      6000000  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 68      3500000                     [{'id': 35, 'name': 'Comedy'}]
# ...         ...                                                ...
# 45280         0  [{'id': 35, 'name': 'Comedy'}, {'id': 99, 'nam...
# 45290         0  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 45311         0                                                 []
# 45380         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 45395   1200000  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
#
#                                                 homepage      id  \
# 9           http://www.mgm.com/view/movie/757/Goldeneye/     710
# 24     http://www.mgm.com/title_title.do?title_star=L...     451
# 46                            http://www.sevenmovie.com/     807
# 49     http://www.mgm.com/#/our-titles/2083/The-Usual...     629
# 68         http://www.newline.com/properties/friday.html   10634
# ...                                                  ...     ...
# 45280             http://www.kinoswiat.pl/film_hiway.asp   60153
# 45290                          http://sivgaatlogeren.nl/  383618
# 45311                             http://grandmalofi.is/  103462
# 45380             https://www.netflix.com/title/80171022  432789
# 45395                                 http://ddpromo.ru/   97797
#
#       original_language                original_title  \
# 9                    en                     GoldenEye
# 24                   en             Leaving Las Vegas
# 46                   en                         Se7en
# 49                   en            The Usual Suspects
# 68                   en                        Friday
# ...                 ...                           ...
# 45280                en                        Hi Way
# 45290                sv               Siv sover vilse
# 45311                en                 Grandma Lo-Fi
# 45380                en  The Incredible Jessica James
# 45395                ru                Мертвые дочери
#
#                                                 overview popularity  \
# 9      James Bond must unmask the mysterious head of ...  14.686036
# 24     Ben Sanderson, an alcoholic Hollywood screenwr...  10.332025
# 46     Two homicide detectives are on a desperate hun...   18.45743
# 49     Held in an L.A. interrogation room, Verbal Kin...  16.302466
# 68     Craig and Smokey are two guys in Los Angeles h...   14.56965
# ...                                                  ...        ...
# 45280  Two young aspiring filmmakers, director Jaco a...    0.08482
# 45290  Seven-year-old Siv’s first night sleeping over...   2.660047
# 45311  At the tender age of 70 years, Sigrídur Níelsd...   0.017109
# 45380  Burned by a bad breakup, a struggling New York...   5.667067
# 45395  In present-day Moscow ghosts of three little g...   0.355732
#
#                                     production_companies  \
# 9      [{'name': 'United Artists', 'id': 60}, {'name'...
# 24     [{'name': 'United Artists', 'id': 60}, {'name'...
# 46     [{'name': 'New Line Cinema', 'id': 12}, {'name...
# 49     [{'name': 'Blue Parrot Productions', 'id': 361...
# 68               [{'name': 'New Line Cinema', 'id': 12}]
# ...                                                  ...
# 45280                                                 []
# 45290  [{'name': 'Viking Film', 'id': 44438}, {'name'...
# 45311                                                 []
# 45380                                                 []
# 45395  [{'name': 'Praktika Pictures', 'id': 9124}, {'...
#
#                                     production_countries release_date  \
# 9      [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   1995-11-16
# 24     [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-27
# 46     [{'iso_3166_1': 'US', 'name': 'United States o...   1995-09-22
# 49     [{'iso_3166_1': 'US', 'name': 'United States o...   1995-07-19
# 68     [{'iso_3166_1': 'US', 'name': 'United States o...   1995-04-26
# ...                                                  ...          ...
# 45280           [{'iso_3166_1': 'PL', 'name': 'Poland'}]   2006-05-02
# 45290  [{'iso_3166_1': 'NL', 'name': 'Netherlands'}, ...   2016-09-28
# 45311                                                 []   2011-11-08
# 45380                                                 []   2017-01-27
# 45395           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2007-02-01
#
#            revenue  runtime  \
# 9      352194034.0    130.0
# 24      49800000.0    112.0
# 46     327311859.0    127.0
# 49      23341568.0    106.0
# 68      28215918.0     91.0
# ...            ...      ...
# 45280          0.0     89.0
# 45290          0.0     79.0
# 45311          0.0     65.0
# 45380          0.0     83.0
# 45395          0.0    123.0
#
#                                         spoken_languages    status  \
# 9      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 24              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 46              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 49     [{'iso_639_1': 'es', 'name': 'Español'}, {'iso...  Released
# 68              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 45280            [{'iso_639_1': 'pl', 'name': 'Polski'}]  Released
# 45290           [{'iso_639_1': 'sv', 'name': 'svenska'}]  Released
# 45311                                                 []  Released
# 45380           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45395           [{'iso_639_1': 'ru', 'name': 'Pусский'}]  Released
#
#                                                  tagline  \
# 9                   No limits. No fears. No substitutes.
# 24                        I Love You... The Way You Are.
# 46                 Seven deadly sins. Seven ways to die.
# 49          Five Criminals. One Line Up. No Coincidence.
# 68     A lot can go down between thursday and saturda...
# ...                                                  ...
# 45280                You gotta see it two to three times
# 45290  Northern lights in the morning. Then it will b...
# 45311         The Basement Tapes of Sigrídur Níelsdóttir
# 45380                      Likes are easy, love is hard.
# 45395                                     Be Good Or Die
#
#                               title  video  vote_average  vote_count
# 9                         GoldenEye  False           6.6      1194.0
# 24                Leaving Las Vegas  False           7.1       365.0
# 46                            Se7en  False           8.1      5915.0
# 49               The Usual Suspects  False           8.1      3334.0
# 68                           Friday  False           7.0       513.0
# ...                             ...    ...           ...         ...
# 45280                        Hi Way  False           7.5         2.0
# 45290             Siv Sleeps Astray  False           0.0         0.0
# 45311                 Grandma Lo-Fi  False           0.0         0.0
# 45380  The Incredible Jessica James  False           6.2        37.0
# 45395                Dead Daughters  False           4.9         5.0
#
# [4402 rows x 20 columns]

# %%
df.reset_index(inplace=True, drop=True)
df
# Out:
#         budget                                             genres  \
# 0     58000000  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 1      3600000  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 2     33000000  [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...
# 3      6000000  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 4      3500000                     [{'id': 35, 'name': 'Comedy'}]
# ...        ...                                                ...
# 4397         0  [{'id': 35, 'name': 'Comedy'}, {'id': 99, 'nam...
# 4398         0  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 4399         0                                                 []
# 4400         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 4401   1200000  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
#
#                                                homepage      id  \
# 0          http://www.mgm.com/view/movie/757/Goldeneye/     710
# 1     http://www.mgm.com/title_title.do?title_star=L...     451
# 2                            http://www.sevenmovie.com/     807
# 3     http://www.mgm.com/#/our-titles/2083/The-Usual...     629
# 4         http://www.newline.com/properties/friday.html   10634
# ...                                                 ...     ...
# 4397             http://www.kinoswiat.pl/film_hiway.asp   60153
# 4398                          http://sivgaatlogeren.nl/  383618
# 4399                             http://grandmalofi.is/  103462
# 4400             https://www.netflix.com/title/80171022  432789
# 4401                                 http://ddpromo.ru/   97797
#
#      original_language                original_title  \
# 0                   en                     GoldenEye
# 1                   en             Leaving Las Vegas
# 2                   en                         Se7en
# 3                   en            The Usual Suspects
# 4                   en                        Friday
# ...                ...                           ...
# 4397                en                        Hi Way
# 4398                sv               Siv sover vilse
# 4399                en                 Grandma Lo-Fi
# 4400                en  The Incredible Jessica James
# 4401                ru                Мертвые дочери
#
#                                                overview popularity  \
# 0     James Bond must unmask the mysterious head of ...  14.686036
# 1     Ben Sanderson, an alcoholic Hollywood screenwr...  10.332025
# 2     Two homicide detectives are on a desperate hun...   18.45743
# 3     Held in an L.A. interrogation room, Verbal Kin...  16.302466
# 4     Craig and Smokey are two guys in Los Angeles h...   14.56965
# ...                                                 ...        ...
# 4397  Two young aspiring filmmakers, director Jaco a...    0.08482
# 4398  Seven-year-old Siv’s first night sleeping over...   2.660047
# 4399  At the tender age of 70 years, Sigrídur Níelsd...   0.017109
# 4400  Burned by a bad breakup, a struggling New York...   5.667067
# 4401  In present-day Moscow ghosts of three little g...   0.355732
#
#                                    production_companies  \
# 0     [{'name': 'United Artists', 'id': 60}, {'name'...
# 1     [{'name': 'United Artists', 'id': 60}, {'name'...
# 2     [{'name': 'New Line Cinema', 'id': 12}, {'name...
# 3     [{'name': 'Blue Parrot Productions', 'id': 361...
# 4               [{'name': 'New Line Cinema', 'id': 12}]
# ...                                                 ...
# 4397                                                 []
# 4398  [{'name': 'Viking Film', 'id': 44438}, {'name'...
# 4399                                                 []
# 4400                                                 []
# 4401  [{'name': 'Praktika Pictures', 'id': 9124}, {'...
#
#                                    production_countries release_date  \
# 0     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   1995-11-16
# 1     [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-27
# 2     [{'iso_3166_1': 'US', 'name': 'United States o...   1995-09-22
# 3     [{'iso_3166_1': 'US', 'name': 'United States o...   1995-07-19
# 4     [{'iso_3166_1': 'US', 'name': 'United States o...   1995-04-26
# ...                                                 ...          ...
# 4397           [{'iso_3166_1': 'PL', 'name': 'Poland'}]   2006-05-02
# 4398  [{'iso_3166_1': 'NL', 'name': 'Netherlands'}, ...   2016-09-28
# 4399                                                 []   2011-11-08
# 4400                                                 []   2017-01-27
# 4401           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2007-02-01
#
#           revenue  runtime                                   spoken_languages  \
# 0     352194034.0    130.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 1      49800000.0    112.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     327311859.0    127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3      23341568.0    106.0  [{'iso_639_1': 'es', 'name': 'Español'}, {'iso...
# 4      28215918.0     91.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...           ...      ...                                                ...
# 4397          0.0     89.0            [{'iso_639_1': 'pl', 'name': 'Polski'}]
# 4398          0.0     79.0           [{'iso_639_1': 'sv', 'name': 'svenska'}]
# 4399          0.0     65.0                                                 []
# 4400          0.0     83.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4401          0.0    123.0           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
#
#         status                                            tagline  \
# 0     Released               No limits. No fears. No substitutes.
# 1     Released                     I Love You... The Way You Are.
# 2     Released              Seven deadly sins. Seven ways to die.
# 3     Released       Five Criminals. One Line Up. No Coincidence.
# 4     Released  A lot can go down between thursday and saturda...
# ...        ...                                                ...
# 4397  Released                You gotta see it two to three times
# 4398  Released  Northern lights in the morning. Then it will b...
# 4399  Released         The Basement Tapes of Sigrídur Níelsdóttir
# 4400  Released                      Likes are easy, love is hard.
# 4401  Released                                     Be Good Or Die
#
#                              title  video  vote_average  vote_count
# 0                        GoldenEye  False           6.6      1194.0
# 1                Leaving Las Vegas  False           7.1       365.0
# 2                            Se7en  False           8.1      5915.0
# 3               The Usual Suspects  False           8.1      3334.0
# 4                           Friday  False           7.0       513.0
# ...                            ...    ...           ...         ...
# 4397                        Hi Way  False           7.5         2.0
# 4398             Siv Sleeps Astray  False           0.0         0.0
# 4399                 Grandma Lo-Fi  False           0.0         0.0
# 4400  The Incredible Jessica James  False           6.2        37.0
# 4401                Dead Daughters  False           4.9         5.0
#
# [4402 rows x 20 columns]

# %%
import nltk
import re
import numpy as np
import contractions

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
f = df[['title', 'tagline', 'overview', 'popularity']]
df.tagline.fillna('', inplace=True)
df['description'] = df['tagline'].map(str) + ' ' + df['overview']
df.dropna(inplace=True)
df['popularity'] = le.fit_transform(df['popularity'].astype(str))
df = df.sort_values(by=['popularity'], ascending=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4402 entries, 29 to 2800
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4402 non-null   object
#  1   genres                4402 non-null   object
#  2   homepage              4402 non-null   object
#  3   id                    4402 non-null   object
#  4   original_language     4402 non-null   object
#  5   original_title        4402 non-null   object
#  6   overview              4402 non-null   object
#  7   popularity            4402 non-null   int32
#  8   production_companies  4402 non-null   object
#  9   production_countries  4402 non-null   object
#  10  release_date          4402 non-null   object
#  11  revenue               4402 non-null   float64
#  12  runtime               4402 non-null   float64
#  13  spoken_languages      4402 non-null   object
#  14  status                4402 non-null   object
#  15  tagline               4402 non-null   object
#  16  title                 4402 non-null   object
#  17  video                 4402 non-null   object
#  18  vote_average          4402 non-null   float64
#  19  vote_count            4402 non-null   float64
#  20  description           4402 non-null   object
# dtypes: float64(4), int32(1), object(16)
# memory usage: 739.4+ KB

# %%
stop_words = nltk.corpus.stopwords.words('english')

def normalize_document(doc):
    # lower case and remove special characters\whitespaces
    doc = re.sub(r'[^a-zA-Z0-9\s]', '', doc, re.I|re.A)
    doc = doc.lower()
    doc = doc.strip()
    doc = contractions.fix(doc)
    # tokenize document
    tokens = nltk.word_tokenize(doc)
    #filter stopwords out of document
    filtered_tokens = [token for token in tokens if token not in stop_words]
    # re-create document from filtered tokens
    doc = ' '.join(filtered_tokens)
    return doc

normalize_corpus = np.vectorize(normalize_document)

norm_corpus = normalize_corpus(list(df['description']))
len(norm_corpus)
# Out:
# 4402

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tf = TfidfVectorizer(ngram_range=(1, 2), min_df=2)
tfidf_matrix = tf.fit_transform(norm_corpus)
tfidf_matrix.shape
# Out:
# (4402, 20295)

# %%
from sklearn.metrics.pairwise import cosine_similarity

doc_sim = cosine_similarity(tfidf_matrix)
doc_sim_df = pd.DataFrame(doc_sim)
doc_sim_df.head()
# Out:
#    0        1         2     3         4        5        6         7     \
# 0   1.0  0.00000  0.000000   0.0  0.000000  0.00000  0.00000  0.007211
# 1   0.0  1.00000  0.000000   0.0  0.005480  0.00000  0.01675  0.000000
# 2   0.0  0.00000  1.000000   0.0  0.019093  0.00000  0.00000  0.000000
# 3   0.0  0.00000  0.000000   1.0  0.000000  0.00000  0.00000  0.022511
# 4   0.0  0.00548  0.019093   0.0  1.000000  0.02393  0.00000  0.013434
#
#        8         9     ...      4392      4393      4394      4395      4396  \
# 0  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000  0.003081
# 1  0.000000  0.021794  ...  0.015646  0.000000  0.000000  0.014635  0.000000
# 2  0.011821  0.023503  ...  0.000000  0.051181  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  ...  0.015366  0.000000  0.000000  0.000000  0.000000
# 4  0.018343  0.014081  ...  0.000000  0.059912  0.012605  0.000000  0.010522
#
#        4397  4398      4399      4400     4401
# 0  0.000000   0.0  0.000000  0.003770  0.00000
# 1  0.000000   0.0  0.012094  0.020734  0.02578
# 2  0.000000   0.0  0.000000  0.008839  0.00000
# 3  0.008722   0.0  0.000000  0.015574  0.00000
# 4  0.008234   0.0  0.000000  0.039851  0.00000
#
# [5 rows x 4402 columns]

# %%
movies_list = df['title'].values
movies_list, movies_list.shape
# Out:
# (array(['Blade Runner', 'The Haunting of Molly Hartley',
#         'The Lords of Salem', ..., 'Everything Must Go',
#         'Young Dragons: Kung Fu Kids II', 'The Great Gatsby'], dtype=object),
#  (4402,))

# %%
movie_idx = np.where(movies_list == 'Blade Runner')[0][0]
movie_idx
# Out:
# 0

# %%
movie_similarities = doc_sim_df.iloc[movie_idx].values
movie_similarities
# Out:
# array([1.        , 0.        , 0.        , ..., 0.        , 0.00376982,
#        0.        ])

# %%
similar_movie_idxs = np.argsort(-movie_similarities)[1:6]
similar_movie_idxs
# Out:
# array([2470, 3102, 2636, 2510, 2263], dtype=int64)

# %%
similar_movies = movies_list[similar_movie_idxs]
similar_movies
# Out:
# array(['Morgan', 'Undiscovered', 'The Soloist', 'Escape from L.A.',
#        'The Children of Huang Shi'], dtype=object)

# %%
def movie_recommender(movie_title, movies=movies_list, doc_sims=doc_sim_df):
    # find movie id
    movie_idx = np.where(movies == movie_title)[0][0]
    # get movie similarities
    movie_similarities = doc_sims.iloc[movie_idx].values
    # get top 5 similar movie IDs
    similar_movie_idxs = np.argsort(-movie_similarities)[1:6]
    # get top 5 movies
    similar_movies = movies[similar_movie_idxs]
    # return the top 5 movies
    return similar_movies

# %%
popular_movies = ['Blade Runner', 'The Haunting of Molly Hartley', 'The Lords of Salem', 'Shaun the Sheep Movie',
              'Choppertown: The Sinners', 'In Custody', 'Everything Must Go', 
              'Young Dragons: Kung Fu Kids II', 'The Great Gatsby', 'The Martian', 'Batman v Superman: Dawn of Justice','Leaves of Grass',
       'Beowulf', 'All the Boys Love Mandy Lane',
       'Christopher and His Kind', 'Attack the Block', 'The Fog',
       'Admiral', 'Baraka', 'Flushed Away', 'Elles', 'Little Birds',
       'The House Bunny', 'Rambo', 'Neighbors 2: Sorority Rising',
       'Alvin and the Chipmunks: The Squeakquel','Funny People', 'Eastern Promises', 'In Bruges', 'Notting Hill',
       'A Dangerous Method', "A Dog's Purpose",
       'The Girl with the Dragon Tattoo', 'Horrible Bosses', 'Eragon',
       'The Duchess', 'The Mechanic', 'The Reaping',
       'Wall Street: Money Never Sleeps', 'Lymelife', 'All Eyez on Me',
       'Knowing', 'Detroit', 'Source Code', 'Crash',
       'The Spy Who Loved Me', 'Live and Let Die', 'Iron Jawed Angels',
       'In a World...', 'Project Nim', 'For Your Eyes Only', 'Starman',
       '30 Minutes or Less', 'Post Grad', 'Little Fockers', 'Gamer','Marley & Me', 'The Colony', 'Nine Dead', 'Boogeyman', 'Air',
       'Arthur', 'Waiting for Forever', 'No Reservations',
       'Happythankyoumoreplease', 'Solomon Kane', 'Fright Night',
       'Animal Kingdom', 'Zero Dark Thirty', 'Time Lapse',
       'American Gangster', 'Case 39', 'Seven Psychopaths',
       'Sky Captain and the World of Tomorrow', 'Severance',
       'The Game Plan', 'According to Greta', 'End of Days', 'Hard Candy',
       'Constantine', 'The Water Diviner', 'Grabbers', 'Pom Poko',
       'In the Valley of Elah', 'Prayers for Bobby', 'Riddick',
       'The Mists of Avalon', 'Nymphomaniac: Vol. II',
       'The Next Three Days', '9th Company', 'The Captains',
       'Into the Woods', 'Haywire', "Grumpy Cat's Worst Christmas Ever",
       'The Promise', 'The Last Airbender', '13 Assassins', 'Rent',
       'J. Edgar', 'Justice League: The Flashpoint Paradox',
       'The Cider House Rules', 'Old Dogs', 'Bronson',
       'The Edge of Seventeen', 'Blitz', 'The Scorpion King','Keeping Up with the Joneses', 'Jonah Hex', 'The Rocker',
       'Journey 2: The Mysterious Island', "Fool's Gold",
       'Million Dollar Arm', 'Victor Frankenstein', 'Heavenly Creatures',
       'March of the Penguins', 'I Love You, Beth Cooper',
       "While We're Young", 'The Walk',
       'Ghost Rider: Spirit of Vengeance', 'Ride Along 2',
       'The Adjustment Bureau', 'I, Frankenstein', 'Grown Ups 2',
       'Tales from Earthsea', 'The Hurt Locker', 'The Way Back',
       'I Am Number Four', 'The Host', 'Hoodwinked Too! Hood VS. Evil',
       'Leatherheads', 'R.I.P.D.', 'Project Almanac', 'Bad Moms',
       "On Her Majesty's Secret Service", "I'm Not There.",
       'In the Land of Women', 'When Marnie Was There', 'Expelled',
       'The Wind Rises', 'The Librarian: The Curse of the Judas Chalice',
       'The Man from Earth', 'The Wolfman', 'Transporter 3', 'Wanderlust',
       'Robot & Frank', 'All About Steve', 'Burlesque', 'Babylon A.D.',
       'The Sum of All Fears', 'Just Go with It',
       'Hunt for the Wilderpeople', 'Reach Me', 'The New Guy',
       'Café Society', 'Gnomeo & Juliet',
       'The Best Exotic Marigold Hotel', 'Pain & Gain',
       'The End of the Tour', 'American Grindhouse', '1408',
       'Swiss Army Man', 'The Fog', 'Dark Places', 'Detour',
       "A Dog's Breakfast", 'Sex and the City', 'Ninja Assassin',
       'G-Force', 'Across the Universe', 'Survival of the Dead',
       'Cop Land', 'Evan Almighty', 'John Dies at the End', 'Moana',
       'Happy Feet Two', 'Hall Pass', 'Ratchet & Clank', 'Step Up 3D',
       'Abraham Lincoln vs. Zombies', 'Invictus', 'Sex Drive',
       'A Hologram for the King', 'Spaceballs', 'Sunshine Cleaning',
       'Duplicity', 'Felon', 'Magnolia', "It's Complicated", 'The Void',
       'Shall We Dance?', 'Head in the Clouds', 'The Bucket List',
       'Tinker Bell', 'After.Life', 'Knocked Up', 'Tracers', 'Religulous',
       'Insidious: Chapter 2', 'The Dukes of Hazzard',
       'The Man from Nowhere', 'Ronal the Barbarian', 'Faster',
       'Two for the Money', 'Brick', 'The Avengers', 'The Circle']

# %%
for movie in popular_movies:
    print('Movie:', movie)
    print('Top 5 recommended Movies:', movie_recommender(movie_title=movie, movies=movies_list, doc_sims=doc_sim_df))
    print()
# Out:
# Movie: Blade Runner
# Top 5 recommended Movies: ['Morgan' 'Undiscovered' 'The Soloist' 'Escape from L.A.'
#  'The Children of Huang Shi']
#
# Movie: The Haunting of Molly Hartley
# Top 5 recommended Movies: ["That's My Boy" 'Blair Witch' "She's Out of My League" 'Darkness'
#  'Harry Potter and the Half-Blood Prince']
#
# Movie: The Lords of Salem
# Top 5 recommended Movies: ['The Sisterhood of Night' 'Prime Evil' "Love's Routine"
#  'How to Seduce Difficult Women' 'Dead Awake']
#
# Movie: Shaun the Sheep Movie
# Top 5 recommended Movies: ['The Fast and the Furious: Tokyo Drift' 'Dark Space'
#  'How to Seduce Difficult Women' 'Tracktown' 'Planet 51']
#
# Movie: Choppertown: The Sinners
# Top 5 recommended Movies: ['Touki Bouki' 'The Motorcycle Diaries' 'CHiPS' 'Mars Attacks!' 'Boats']
#
# Movie: In Custody
# Top 5 recommended Movies: ['Ship of Theseus' 'The Monkey King' 'Outsourced'
#  'The Man Who Knew Infinity' 'Good for Nothing']
#
# Movie: Everything Must Go
# Top 5 recommended Movies: ['The Possession' 'The Ant Bully' 'I, Frankenstein' 'You Kill Me'
#  'Red Wine in the Dark Night']
#
# Movie: Young Dragons: Kung Fu Kids II
# Top 5 recommended Movies: ['Kung Fury' 'Kung Fu Panda 2'
#  'Kung Fu Panda: Secrets of the Furious Five' 'The Karate Kid' 'Ip Man']
#
# Movie: The Great Gatsby
# Top 5 recommended Movies: ['L.I.E.'
#  'The 100 Year-Old Man Who Climbed Out the Window and Disappeared'
#  'Paper Man' 'Bambi' 'Lost & Found']
#
# Movie: The Martian
# Top 5 recommended Movies: ['The Last Man on Earth' 'Astronaut: The Last Push' 'Terra Formars'
#  'The Space Between Us' 'The Losers']
#
# Movie: Batman v Superman: Dawn of Justice
# Top 5 recommended Movies: ['John Doe: Vigilante' 'Batman: Under the Red Hood'
#  'Lego Batman: The Movie - DC Super Heroes Unite' 'The Punisher'
#  'Green Lantern: First Flight']
#
# Movie: Leaves of Grass
# Top 5 recommended Movies: ['Cannibal Holocaust' 'Pusher' 'The Raid' 'Casa De Mi Padre' 'Found']
#
# Movie: Beowulf
# Top 5 recommended Movies: ['Shrek Forever After' 'Beowulf & Grendel' 'Solomon Kane'
#  "What's Your Number?" 'My Mistress']
#
# Movie: All the Boys Love Mandy Lane
# Top 5 recommended Movies: ['Mamaboy' 'Beastly' '21 Jump Street' 'In God We Teach' 'The Black Hole']
#
# Movie: Christopher and His Kind
# Top 5 recommended Movies: ['Elvis and Anabelle' 'Lessons of a Dream'
#  "It's Only the End of the World" 'Young Adult' 'Collision']
#
# Movie: Attack the Block
# Top 5 recommended Movies: ['The 5th Wave' 'Frenemies' 'The Iron Giant' 'Lazer Team' 'Space Tourists']
#
# Movie: The Fog
# Top 5 recommended Movies: ['Captain Phillips' 'Asian School Girls' 'Gangs of New York'
#  'Rocky Balboa' 'Headless']
#
# Movie: Admiral
# Top 5 recommended Movies: ['Little England' 'Winter in Wartime' 'The Good, the Bad and the Ugly'
#  'War Don Don' 'The Princess of Montpensier']
#
# Movie: Baraka
# Top 5 recommended Movies: ['The Book Thief' 'Being Ginger' 'Million Dollar Baby' 'Stardust'
#  'The Northlander']
#
# Movie: Flushed Away
# Top 5 recommended Movies: ['The Tale of Despereaux' 'Ratatouille' 'The Last Seven'
#  "Bailey's Billion$" 'Ice Age: Continental Drift']
#
# Movie: Elles
# Top 5 recommended Movies: ['Cougars, Inc.' 'Prater' 'X' 'Believe Me' 'Waking Madison']
#
# Movie: Little Birds
# Top 5 recommended Movies: ['The Missing' 'Leave to Remain' 'Exam' 'Jamie Marks Is Dead'
#  'The Talented Mr. Ripley']
#
# Movie: The House Bunny
# Top 5 recommended Movies: ['The Beach Girls' 'Damsels in Distress' 'Fired Up!'
#  'Bikini Model Academy' 'The Guest House']
#
# Movie: Rambo
# Top 5 recommended Movies: ['Austin Powers in Goldmember' 'In the Land of Blood and Honey'
#  'Rurouni Kenshin' 'Apocalypse Now' 'The Legend of Ben Hall']
#
# Movie: Neighbors 2: Sorority Rising
# Top 5 recommended Movies: ['Everything, Everything' 'Fright Night' 'Sisters' 'Frozen City'
#  'Keeping Up with the Joneses']
#
# Movie: Alvin and the Chipmunks: The Squeakquel
# Top 5 recommended Movies: ['Alvin and the Chipmunks' 'Alvin and the Chipmunks: Chipwrecked'
#  'Alvin and the Chipmunks: The Road Chip' 'The Wild' 'The Winding Stream']
#
# Movie: Funny People
# Top 5 recommended Movies: ["George Lopez: It's Not Me, It's You" 'Hollywoodland' 'To Be Takei'
#  "The King's Speech" 'Mean Girls']
#
# Movie: Eastern Promises
# Top 5 recommended Movies: ['The Secret Life of Marilyn Monroe' 'Rage' 'The Last Station'
#  'The Battalion' 'Comforting Skin']
#
# Movie: In Bruges
# Top 5 recommended Movies: ['Triple Tap' 'Redirected' "Dancin' It's On" 'The Lords of Salem'
#  'Hollywood Without Make-Up']
#
# Movie: Notting Hill
# Top 5 recommended Movies: ['Hitchcock' 'Teri Meri Kahaani' '1066: The Battle for Middle Earth'
#  'The Other Half' 'The Star of Bethlehem']
#
# Movie: A Dangerous Method
# Top 5 recommended Movies: ['Manhole' 'Mega Man' 'Mystery Team'
#  'Kung Fu Panda: Secrets of the Masters' 'The 7:39']
#
# Movie: A Dog's Purpose
# Top 5 recommended Movies: ['Corner Gas: The Movie' 'Underdog' 'Good Boy!' 'Sausage Party'
#  'Frankenweenie']
#
# Movie: The Girl with the Dragon Tattoo
# Top 5 recommended Movies: ['The Girl Who Played with Fire' 'The Girl with the Dragon Tattoo'
#  'Mystery Team' "The Girl Who Kicked the Hornet's Nest"
#  'Big Boys Gone Bananas!*']
#
# Movie: Horrible Bosses
# Top 5 recommended Movies: ['Nearing Grace' 'Term Life' '6 Days to Air: The Making of South Park'
#  'Zack and Miri Make a Porno' 'New York']
#
# Movie: Eragon
# Top 5 recommended Movies: ['How to Train Your Dragon 2' 'Age of the Dragons' 'Robin Hood'
#  'The Water Horse' 'Dragonlance: Dragons Of Autumn Twilight']
#
# Movie: The Duchess
# Top 5 recommended Movies: ['For Greater Glory - The True Story of Cristiada' 'Unbroken'
#  'Perfume: The Story of a Murderer' 'Concussion' 'The Alphabet Killer']
#
# Movie: The Mechanic
# Top 5 recommended Movies: ['Saint' 'Traders' 'Killers' 'John Bishop Supersonic Live' 'Cream']
#
# Movie: The Reaping
# Top 5 recommended Movies: ['Dead Awake' 'The Witch' 'Hoovey' 'Reaper' 'Wither']
#
# Movie: Wall Street: Money Never Sleeps
# Top 5 recommended Movies: ['The Flaw' 'The Wolf of Wall Street' 'A Mighty Heart'
#  "Madea's Witness Protection" 'Kiss The Bride']
#
# Movie: Lymelife
# Top 5 recommended Movies: ['Blush' 'American Winter' 'One Hundred Mornings' 'L.I.E.' 'Paper Man']
#
# Movie: All Eyez on Me
# Top 5 recommended Movies: ['Tupac: Resurrection' 'The Legend of Ben Hall' 'One on Top of the Other'
#  'Winnie Mandela' 'The Fear of 13']
#
# Movie: Knowing
# Top 5 recommended Movies: ['Life in a Day' 'The Circle' 'The Vessel' 'A Horse for Summer'
#  '5 Centimeters per Second']
#
# Movie: Detroit
# Top 5 recommended Movies: ['Territories' 'The Eleventh Hour' 'Burn' 'Last Call at the Oasis'
#  'Superpower']
#
# Movie: Source Code
# Top 5 recommended Movies: ['Last Passenger' 'The Railroad Lady' 'Snowpiercer' 'Bad Ass'
#  'The Ultimate Life']
#
# Movie: Crash
# Top 5 recommended Movies: ['Undiscovered' 'XOXO' 'Burning Palms' 'Escape from L.A.' 'The Soloist']
#
# Movie: The Spy Who Loved Me
# Top 5 recommended Movies: ['For Your Eyes Only' 'A View to a Kill' 'Live and Let Die'
#  'Never Say Never Again' 'Octopussy']
#
# Movie: Live and Let Die
# Top 5 recommended Movies: ['A View to a Kill' 'Octopussy' 'For Your Eyes Only'
#  'Never Say Never Again' 'GoldenEye']
#
# Movie: Iron Jawed Angels
# Top 5 recommended Movies: ['The Black Power Mixtape 1967-1975' 'Dark Girls' 'For Colored Girls'
#  'Hunt for the Wilderpeople' 'Clash of the Titans']
#
# Movie: In a World...
# Top 5 recommended Movies: ["The King's Speech" 'I Am Jane Doe' 'The Aerial' 'Beyond the Lights'
#  'Radio Rebel']
#
# Movie: Project Nim
# Top 5 recommended Movies: ['Human' 'Breakfast on Pluto' 'Being in the World' 'The Thing'
#  'My Beautiful Broken Brain']
#
# Movie: For Your Eyes Only
# Top 5 recommended Movies: ['Octopussy' 'Never Say Never Again' 'Live and Let Die'
#  'The Man with the Golden Gun' "On Her Majesty's Secret Service"]
#
# Movie: Starman
# Top 5 recommended Movies: ['Peace, Love & Misunderstanding' 'Space Chimps 2: Zartog Strikes Back'
#  'Old Fashioned: The Story of the Wisconsin Supper Club'
#  'A Beautiful Planet' 'Boats']
#
# Movie: 30 Minutes or Less
# Top 5 recommended Movies: ['The Tough Ones' 'Zombie Pizza' 'Wild Hogs' 'Fargo'
#  'Lock, Stock and Two Smoking Barrels']
#
# Movie: Post Grad
# Top 5 recommended Movies: ['Adventureland' 'How to Build a Better Boy' '2:22' 'The Perfect Guy'
#  'The Shaggy Dog']
#
# Movie: Little Fockers
# Top 5 recommended Movies: ['Meet the Fockers' 'The Square' "Liar's Moon" 'Jack the Giant Killer'
#  "Stephen Tobolowsky's Birthday Party"]
#
# Movie: Gamer
# Top 5 recommended Movies: ['Narcopolis' 'Nerve' 'Beta Test' 'THX 1138' 'Pixels']
#
# Movie: Marley & Me
# Top 5 recommended Movies: ['On the Road' 'Beautiful Boy' 'Home Sweet Home' 'Corner Gas: The Movie'
#  'Last Night']
#
# Movie: The Colony
# Top 5 recommended Movies: ['Cyborg X' 'Ice Age: The Meltdown' 'Age of Ice' 'Legend' 'The Watermen']
#
# Movie: Nine Dead
# Top 5 recommended Movies: ['Cat Sick Blues' 'Before Sunset' 'Girl Rising' 'First Sunday'
#  'Elstree 1976']
#
# Movie: Boogeyman
# Top 5 recommended Movies: ['Stanley' 'Boogeyman 2' 'Cropsey' 'Lost Angels'
#  'Extremely Loud & Incredibly Close']
#
# Movie: Air
# Top 5 recommended Movies: ['Narcopolis' 'Brooklyn' 'Born to Raise Hell' 'RWD' 'Man of Steel']
#
# Movie: Arthur
# Top 5 recommended Movies: ['Vanessa' 'Home Alone' 'Beatriz at Dinner'
#  'Beyond the Valley of the Dolls' 'The Talented Mr. Ripley']
#
# Movie: Waiting for Forever
# Top 5 recommended Movies: ['The Sweetest Thing' 'Aquí Entre Nos' 'Sequoia' 'Maze' 'Around June']
#
# Movie: No Reservations
# Top 5 recommended Movies: ['After the Ball' 'Barefoot' 'Memoirs of an Invisible Man'
#  'Like Water for Chocolate' "I Don't Know How She Does It"]
#
# Movie: Happythankyoumoreplease
# Top 5 recommended Movies: ['Ceremony' 'Young Black Stallion' 'Red Wine in the Dark Night' 'Pulsar'
#  'Bling']
#
# Movie: Solomon Kane
# Top 5 recommended Movies: ['The Unborn' 'Cross' 'Les Misérables' 'The Princess of Montpensier'
#  'Iron Man']
#
# Movie: Fright Night
# Top 5 recommended Movies: ['Blade' 'Stake Land' 'Neighbors 2: Sorority Rising' 'St. Vincent'
#  'Blade II']
#
# Movie: Animal Kingdom
# Top 5 recommended Movies: ['Blue Ruin' 'Logan' 'The Babadook' 'Dirt' 'Hulchul']
#
# Movie: Zero Dark Thirty
# Top 5 recommended Movies: ['Loose Change: 2nd Edition' 'Tere Bin Laden' 'Patriots Day'
#  'Lone Survivor' 'The Pacifier']
#
# Movie: Time Lapse
# Top 5 recommended Movies: ['Churchill' 'The Last Mimzy' 'Transpecos' 'New York' 'Journey to Le Mans']
#
# Movie: American Gangster
# Top 5 recommended Movies: ['War Dogs' 'Park Avenue: Money, Power & The American Dream'
#  'The Alphabet Killer' 'Territories' 'Narco Cultura']
#
# Movie: Case 39
# Top 5 recommended Movies: ['The Big Sick' 'Crazy, Stupid, Love.' 'Wuthering Heights' 'Operator'
#  'Elektra']
#
# Movie: Seven Psychopaths
# Top 5 recommended Movies: ['Brother' 'Time Again' 'Undiscovered' 'Escape from L.A.'
#  'The Transporter Refueled']
#
# Movie: Sky Captain and the World of Tomorrow
# Top 5 recommended Movies: ['The Taking of Pelham 1 2 3' 'Star Trek: Of Gods And Men' 'Body of Lies'
#  'Reign Over Me' 'Prime Evil']
#
# Movie: Severance
# Top 5 recommended Movies: ['Hush' 'Final Destination 5' 'Baseline' 'Boogeyman'
#  'Mile... Mile & A Half']
#
# Movie: The Game Plan
# Top 5 recommended Movies: ['Bangkok Dangerous' 'Enduring Love'
#  'How Do You Write a Joe Schermann Song' '23 Blast' 'Somersault']
#
# Movie: According to Greta
# Top 5 recommended Movies: ['Oktapodi' 'The Visit' 'The Butterfly Tattoo' 'Patrik, Age 1.5'
#  'The Princess and the Frog']
#
# Movie: End of Days
# Top 5 recommended Movies: ['Prime Evil' 'Sam' 'Tracers' 'Rubble Kings' 'The Night Before']
#
# Movie: Hard Candy
# Top 5 recommended Movies: ['Hot Girls Wanted' "My Girlfriend's Boyfriend" 'Dead Daughters' 'Wake'
#  'Ryna']
#
# Movie: Constantine
# Top 5 recommended Movies: ['Jack and Jill' "Julia's Eyes" 'Dogma' 'Manborg' 'Reboot']
#
# Movie: The Water Diviner
# Top 5 recommended Movies: ['The Eagle' 'Resident Evil: Extinction' 'Mad Max: Fury Road' 'Lazy Eye'
#  'Curious George 2: Follow That Monkey!']
#
# Movie: Grabbers
# Top 5 recommended Movies: ['Blair Witch' 'Going the Distance' 'Little Dead Rotting Hood'
#  'Red Billabong' 'Djinn']
#
# Movie: Pom Poko
# Top 5 recommended Movies: ['Black Water' 'Leningrad' 'Look' 'Bandslam'
#  'Puppetry of the Penis: Live at the Forum']
#
# Movie: In the Valley of Elah
# Top 5 recommended Movies: ['Stop-Loss' 'Exposed' 'Stolen' 'Freedomland' 'Abduction']
#
# Movie: Prayers for Bobby
# Top 5 recommended Movies: ["Charlie Wilson's War" 'Beautiful Boy' 'Asian School Girls'
#  "The Chemical Brothers: Don't Think" 'Miracles from Heaven']
#
# Movie: Riddick
# Top 5 recommended Movies: ['Pitch Black' 'Bounty Hunters' 'The Revenant' 'Soldier'
#  'Threads of Destiny']
#
# Movie: The Mists of Avalon
# Top 5 recommended Movies: ['Meet the Mormons' 'Burn' 'Iron Man 3' 'Avalon' 'Body Bags']
#
# Movie: Nymphomaniac: Vol. II
# Top 5 recommended Movies: ['What Maisie Knew' 'Elektra Luxx' 'Night Train to Lisbon' 'Diet of Sex'
#  'Efectos secundarios']
#
# Movie: The Next Three Days
# Top 5 recommended Movies: ['Rabbit Hole' 'The Promise' "Smokin' Aces" 'Weekend Pass' 'Stop-Loss']
#
# Movie: 9th Company
# Top 5 recommended Movies: ["The Huntsman: Winter's War" 'Snow White and the Huntsman' 'Green Zone'
#  'No' 'The Monuments Men']
#
# Movie: The Captains
# Top 5 recommended Movies: ['Nas: Time Is Illmatic'
#  'Leviathan: The Story of Hellraiser and Hellbound: Hellraiser II'
#  'Food Choices' 'McLibel' 'Which Way Home']
#
# Movie: Into the Woods
# Top 5 recommended Movies: ['Wish Upon' "Happily N'Ever After" 'Into the Woods' 'Life After Beth'
#  'Don’t Stop Believin’: Everyman’s Journey']
#
# Movie: Haywire
# Top 5 recommended Movies: ['Crank: High Voltage' 'The Revenant' 'Safe House' 'Skyfall' 'Blood Moon']
#
# Movie: Grumpy Cat's Worst Christmas Ever
# Top 5 recommended Movies: ['Cool Cat Saves the Kids' 'Love Hina Christmas Special: Silent Eve'
#  'A Muppet Family Christmas' 'Bad Cat' 'Cat Sick Blues']
#
# Movie: The Promise
# Top 5 recommended Movies: ['Eungyo' 'How Do You Know' 'Tumbledown' 'Despite the Falling Snow'
#  'The Other Half']
#
# Movie: The Last Airbender
# Top 5 recommended Movies: ['The High Sun' "Shana: The Wolf's Music"
#  'Atlas Shrugged Part III: Who is John Galt?' 'The Wild' 'Seabiscuit']
#
# Movie: 13 Assassins
# Top 5 recommended Movies: ['Kill' 'Into the Woods' 'The Tracker' 'Prohibition' 'Brave']
#
# Movie: Rent
# Top 5 recommended Movies: ['Kidulthood' 'Shuffle' 'Brokeback Mountain' "Don't Think Twice"
#  'Band of Robbers']
#
# Movie: J. Edgar
# Top 5 recommended Movies: ['Public Enemies' "Muhammad Ali's Greatest Fight" 'John Adams' 'RoboCop'
#  'Love in the Time of Cholera']
#
# Movie: Justice League: The Flashpoint Paradox
# Top 5 recommended Movies: ['Justice League: War' 'Synchronicity'
#  'Justice League: Throne of Atlantis' 'Justice League: Gods and Monsters'
#  'Justice League: Doom']
#
# Movie: The Cider House Rules
# Top 5 recommended Movies: ['The Simpsons Movie' 'Mega Man' 'The Giant Spider Invasion'
#  "Dr. Horrible's Sing-Along Blog" 'Bloodlust!']
#
# Movie: Old Dogs
# Top 5 recommended Movies: ['Dan in Real Life' '8 Minutes Idle' 'Harmontown' 'My Mistress'
#  'Austin Powers in Goldmember']
#
# Movie: Bronson
# Top 5 recommended Movies: ['True Memoirs of an International Assassin' 'Ong Bak 2' 'Spider-Man 3'
#  'Deadpool' 'Back in Time']
#
# Movie: The Edge of Seventeen
# Top 5 recommended Movies: ['Heidi' 'Mamaboy' '21 Jump Street' 'Sex Drive'
#  'Blue Lagoon: The Awakening']
#
# Movie: Blitz
# Top 5 recommended Movies: ['Lucky' 'Kalifornia' 'Manhole' "Don't Let Him In" 'R.I.P.D.']
#
# Movie: The Scorpion King
# Top 5 recommended Movies: ['The Scorpion King: Rise of a Warrior' 'Perrier’s Bounty' 'Four Brothers'
#  'The Magnificent Seven' 'Ninja Assassin']
#
# Movie: Keeping Up with the Joneses
# Top 5 recommended Movies: ['Swinging with the Finkels' 'Men to Kiss' 'Frozen City' 'After Porn Ends'
#  'The Ones Below']
#
# Movie: Jonah Hex
# Top 5 recommended Movies: ['Adaptation.' 'The Haunting in Connecticut' 'Hurricane Bianca'
#  'A Man Apart' 'Fantastic Mr. Fox']
#
# Movie: The Rocker
# Top 5 recommended Movies: ['We Are X' "Quiet Riot: Well Now You're Here, There's No Way Back"
#  'Sepultura: Under Siege (Live in Barcelona)' 'Rock the Kasbah' 'Dead End']
#
# Movie: Journey 2: The Mysterious Island
# Top 5 recommended Movies: ['Blackbird' 'Little Boy' 'Lost & Found' 'Percy Jackson: Sea of Monsters'
#  'The Croods']
#
# Movie: Fool's Gold
# Top 5 recommended Movies: ['Burlesque' 'Love Birds' 'Lost & Found' 'Letters to Juliet'
#  'Home Alone: The Holiday Heist']
#
# Movie: Million Dollar Arm
# Top 5 recommended Movies: ['Free to Play' 'Pixels' 'I Got Next' 'Four Days in October'
#  'Calvin Marshall']
#
# Movie: Victor Frankenstein
# Top 5 recommended Movies: ['The Maker' 'Attack of the Lederhosen Zombies' 'Experimenter'
#  'Hatchet III' 'Human Nature']
#
# Movie: Heavenly Creatures
# Top 5 recommended Movies: ["A Mother's Nightmare" 'The Alphabet Killer' 'In the Heart of the Sea'
#  "Charlie Wilson's War" 'Megan is Missing']
#
# Movie: March of the Penguins
# Top 5 recommended Movies: ['Happy Feet' 'Madagascar: Escape 2 Africa' 'Island of Lemurs: Madagascar'
#  'Snow Beast' "Manson's Lost Girls"]
#
# Movie: I Love You, Beth Cooper
# Top 5 recommended Movies: ['21 Jump Street' 'Sunshine Superman'
#  'Margaret Thatcher: The Long Walk to Finchley' 'G.B.F.' 'Dirty Girl']
#
# Movie: While We're Young
# Top 5 recommended Movies: ['The Intern' 'Bad Ass 2: Bad Asses' 'Young Adult' 'The Nines' 'Eungyo']
#
# Movie: The Walk
# Top 5 recommended Movies: ['Man on Wire' 'The Art of Travel' 'The Yes Men' 'Miami Connection'
#  "See What I'm Saying: The Deaf Entertainers Documentary"]
#
# Movie: Ghost Rider: Spirit of Vengeance
# Top 5 recommended Movies: ['Ghost Rider' 'Growing Up Smith' 'Meet Dave'
#  'Killer Tomatoes Strike Back!' 'Dredd']
#
# Movie: Ride Along 2
# Top 5 recommended Movies: ['On the Outs' 'Sacrifice' 'Super' 'Boone: The Bounty Hunter'
#  'Run, Fatboy, Run']
#
# Movie: The Adjustment Bureau
# Top 5 recommended Movies: ['Deuces Wild' 'Rubble Kings' 'We Cause Scenes' 'Green Lantern'
#  'Trancers 6: Life After Deth']
#
# Movie: I, Frankenstein
# Top 5 recommended Movies: ['Cat Run' 'The Mortal Instruments: City of Bones' 'The Unwanted'
#  'The Dark Tower' 'Southland Tales']
#
# Movie: Grown Ups 2
# Top 5 recommended Movies: ['Fido' 'Juno' 'Band of Robbers' 'Going Down in La-La Land'
#  "Madea's Witness Protection"]
#
# Movie: Tales from Earthsea
# Top 5 recommended Movies: ['How to Train Your Dragon 2' 'Eragon' 'The Wizard of Oz'
#  'Children of Men' 'My Life in Ruins']
#
# Movie: The Hurt Locker
# Top 5 recommended Movies: ['Blown Away' 'The Wall' 'As the Gods Will' 'Hunter Prey' 'Step Up All In']
#
# Movie: The Way Back
# Top 5 recommended Movies: ['One Little Pill' 'Wyrmwood: Road Of The Dead' 'Hammer & Tickle'
#  'Beverly Hills Chihuahua 3 - Viva La Fiesta!' 'The Giants']
#
# Movie: I Am Number Four
# Top 5 recommended Movies: ['The History of Eternity' 'XX' 'Altitude' 'The Dukes of Hazzard'
#  'The Ledge']
#
# Movie: The Host
# Top 5 recommended Movies: ['The Chosen' 'Kinyarwanda' 'Battle of Los Angeles' 'The Water Horse'
#  'Victor Frankenstein']
#
# Movie: Hoodwinked Too! Hood VS. Evil
# Top 5 recommended Movies: ['Hansel & Gretel: Witch Hunters' 'Batman: Under the Red Hood'
#  'Hoodwinked!' 'To Write Love on Her Arms'
#  'Barbie: Mariposa and The Fairy Princess']
#
# Movie: Leatherheads
# Top 5 recommended Movies: ['Pony Excess' 'Admiral' 'Card Subject To Change'
#  'Margaret Thatcher: The Long Walk to Finchley' 'The Guest House']
#
# Movie: R.I.P.D.
# Top 5 recommended Movies: ['Blitz' 'Freaks of Nature' 'El niño' 'I Love You, Man'
#  'Phantasm IV: Oblivion']
#
# Movie: Project Almanac
# Top 5 recommended Movies: ['Disturbia' 'Mercury Plains' 'Timecrimes' 'Shinjuku Incident' 'Spin']
#
# Movie: Bad Moms
# Top 5 recommended Movies: ['Burden' 'This Is the End' 'Office Christmas Party'
#  'Future Shock! The Story of 2000AD' 'The Magic of Belle Isle']
#
# Movie: On Her Majesty's Secret Service
# Top 5 recommended Movies: ['Never Say Never Again' 'Diamonds Are Forever' 'For Your Eyes Only'
#  'You Only Live Twice' 'The Man with the Golden Gun']
#
# Movie: I'm Not There.
# Top 5 recommended Movies: ["The Ballad of Ramblin' Jack" 'One Last Thing...'
#  'Lost Songs: The Basement Tapes Continued' 'The Last Waltz'
#  'Meet the Mormons']
#
# Movie: In the Land of Women
# Top 5 recommended Movies: ['What Goes Up' 'Boats' 'The Incredible Jessica James' 'Short Term 12'
#  'Groupie']
#
# Movie: When Marnie Was There
# Top 5 recommended Movies: ['Morgana' "Don't Be Afraid of the Dark" "Cowgirls n' Angels"
#  'Girl Rising' 'Rock the Kasbah']
#
# Movie: Expelled
# Top 5 recommended Movies: ['Mamaboy' '21 Jump Street' 'Heidi' 'The New Guy' 'Kids in America']
#
# Movie: The Wind Rises
# Top 5 recommended Movies: ['Letters from Iwo Jima' 'Unbroken' 'Five Came Back' 'Memoirs of a Geisha'
#  'The Rape of Europa']
#
# Movie: The Librarian: The Curse of the Judas Chalice
# Top 5 recommended Movies: ['TRON: Legacy' 'Chinese Zodiac' 'The Invention of Lying' 'Tangled'
#  'Children of Heaven']
#
# Movie: The Man from Earth
# Top 5 recommended Movies: ['Night Train to Lisbon' 'X' 'Adaptation.'
#  'Pax Americana and the Weaponization of Space'
#  'Pokémon: The Rise of Darkrai']
#
# Movie: The Wolfman
# Top 5 recommended Movies: ['Some Girl(s)' 'The Judge' 'North Beach' 'The Hooligan Factory'
#  'Apollo 18']
#
# Movie: Transporter 3
# Top 5 recommended Movies: ['The Transporter Refueled' 'Chennai Express' 'JohnnyExpress' 'Inhale'
#  'Echelon Conspiracy']
#
# Movie: Wanderlust
# Top 5 recommended Movies: ['Commune' 'Around June' 'My Queen Karo' 'The Ones Below'
#  'How to Seduce Difficult Women']
#
# Movie: Robot & Frank
# Top 5 recommended Movies: ["Everybody's Fine" 'The Leisure Class' 'Robot Stories' 'WALL·E'
#  'La Santa Muerte']
#
# Movie: All About Steve
# Top 5 recommended Movies: ['Frozen' 'Flipped' 'Efectos secundarios' "Winter's Tale" 'Trapped']
#
# Movie: Burlesque
# Top 5 recommended Movies: ["Fool's Gold" 'The Princess and the Frog' 'Dhoom' 'You Get Me'
#  "Ocean's Eleven"]
#
# Movie: Babylon A.D.
# Top 5 recommended Movies: ['Delhi Belly' 'Redirected' 'Sam' 'Prime Evil' 'The Girl on the Train']
#
# Movie: The Sum of All Fears
# Top 5 recommended Movies: ['The November Man' 'A Good Day to Die Hard' "Pandora's Promise"
#  'The Hunt for Red October' "Cowgirls n' Angels"]
#
# Movie: Just Go with It
# Top 5 recommended Movies: ['Opposite Day' 'Free to Play' 'Dostana' 'The Infinite Man' 'Black Widow']
#
# Movie: Hunt for the Wilderpeople
# Top 5 recommended Movies: ['The Wild' 'Spirit Camp' 'Iron Jawed Angels' 'Bride Flight'
#  'Justice League: War']
#
# Movie: Reach Me
# Top 5 recommended Movies: ['Scream 4' 'The Wayshower' 'Atlas Shrugged Part III: Who is John Galt?'
#  'Devil' 'Head Games']
#
# Movie: The New Guy
# Top 5 recommended Movies: ['Spider-Man' 'Sex Drive' 'Mamaboy' '21 Jump Street' 'Monster Trucks']
#
# Movie: Café Society
# Top 5 recommended Movies: ['I am Fishead' 'The Beauty Inside' 'Amélie' 'Feast of Love'
#  'Wolf Children']
#
# Movie: Gnomeo & Juliet
# Top 5 recommended Movies: ['Camille' 'Equals' 'Romeo + Juliet' 'The Time Machine'
#  'Letters to Juliet']
#
# Movie: The Best Exotic Marigold Hotel
# Top 5 recommended Movies: ['Insane' 'Beverly Hills Chihuahua 3 - Viva La Fiesta!' 'Cold Prey'
#  'Hotel Rwanda' 'Megamind']
#
# Movie: Pain & Gain
# Top 5 recommended Movies: ['Fightville' 'Shenandoah' 'Live by Night' 'Anjaana Anjaani' 'War Dogs']
#
# Movie: The End of the Tour
# Top 5 recommended Movies: ['Fast Getaway' 'David and Goliath' 'We Are Many'
#  "A Birder's Guide to Everything" 'Creative Control']
#
# Movie: American Grindhouse
# Top 5 recommended Movies: ['Pump' 'Room 237' 'Picasso and Braque Go to the Movies'
#  'Drunk Stoned Brilliant Dead: The Story of the National Lampoon'
#  'The Human Experiment']
#
# Movie: 1408
# Top 5 recommended Movies: ['Room' "Fermat's Room" 'Room in Rome' 'The Reaping'
#  'Mardi Gras: Spring Break']
#
# Movie: Swiss Army Man
# Top 5 recommended Movies: ['I Saw the Light' 'Salvage' 'Particle Fever' 'Kalifornia' 'Before I Fall']
#
# Movie: The Fog
# Top 5 recommended Movies: ['Captain Phillips' 'Asian School Girls' 'Gangs of New York'
#  'Rocky Balboa' 'Headless']
#
# Movie: Dark Places
# Top 5 recommended Movies: ['The Debt' 'Dead Within' '13Hrs' 'Bill Cosby: Far From Finished'
#  'Last Girl Standing']
#
# Movie: Detour
# Top 5 recommended Movies: ['Everything Must Go' 'The Summoning' 'Azumi 2: Death or Love' 'G.B.F.'
#  '23 Blast']
#
# Movie: A Dog's Breakfast
# Top 5 recommended Movies: ['The Shaggy Dog' 'Living Will...' 'Rabbit Hole' 'Unhung Hero' 'Wither']
#
# Movie: Sex and the City
# Top 5 recommended Movies: ['Live and Let Die' 'For the Love of Spock'
#  "Mr. Magorium's Wonder Emporium" 'On the Edge' 'The Back-Up Plan']
#
# Movie: Ninja Assassin
# Top 5 recommended Movies: ['Four Brothers' 'Azumi 2: Death or Love' 'Gothic & Lolita Psycho'
#  'Death Machines' 'Perrier’s Bounty']
#
# Movie: G-Force
# Top 5 recommended Movies: ['xXx' 'The Kingdom' 'Team America: World Police' 'Doogal'
#  'Empire of Corpses']
#
# Movie: Across the Universe
# Top 5 recommended Movies: ['Teri Meri Kahaani' 'Les Misérables' 'Like Crazy' 'Equals'
#  'Blood Brother']
#
# Movie: Survival of the Dead
# Top 5 recommended Movies: ['House of the Dead' 'Maggie' 'The Princess and the Frog'
#  "Devil's Playground" 'Moonrise Kingdom']
#
# Movie: Cop Land
# Top 5 recommended Movies: ['A Nightmare on Elm Street' 'Blitz' 'Arrival' 'Red Hill'
#  'The Secret World of Arrietty']
#
# Movie: Evan Almighty
# Top 5 recommended Movies: ['Ooops! Noah is Gone...' 'Noah' 'Fist of Jesus' 'Call Girl of Cthulhu'
#  'The Great Wall']
#
# Movie: John Dies at the End
# Top 5 recommended Movies: ['In a Day' 'The Road' 'White Frog' 'The Subjects' 'April Showers']
#
# Movie: Moana
# Top 5 recommended Movies: ['Happy Feet Two' 'Badmaash Company' 'Brave'
#  'Tinker Bell and the Lost Treasure' 'Fast Getaway']
#
# Movie: Happy Feet Two
# Top 5 recommended Movies: ['The Wrong Trousers' 'Happy Feet' 'Moana'
#  'American Pie Presents: The Naked Mile' 'Step Up All In']
#
# Movie: Hall Pass
# Top 5 recommended Movies: ['Alcan Highway' 'First Sunday' 'Heartbreaker'
#  'Love Hina Christmas Special: Silent Eve' 'Thank You']
#
# Movie: Ratchet & Clank
# Top 5 recommended Movies: ['Power Rangers' 'Threads of Destiny' 'The Night Watchmen'
#  'Scouts Guide to the Zombie Apocalypse'
#  'LEGO DC Comics Super Heroes: Justice League vs. Bizarro League']
#
# Movie: Step Up 3D
# Top 5 recommended Movies: ['High Strung' 'Warcraft' 'This Is The Life' 'Free to Play' '8 Mile']
#
# Movie: Abraham Lincoln vs. Zombies
# Top 5 recommended Movies: ['Allied' 'The Conspirator' 'Outpost: Black Sun' 'The Monuments Men'
#  'National Treasure: Book of Secrets']
#
# Movie: Invictus
# Top 5 recommended Movies: ['Winnie Mandela' 'Lusers' 'Adventureland' 'Budrus' 'Cars']
#
# Movie: Sex Drive
# Top 5 recommended Movies: ['The New Guy' 'Mamaboy' 'Nerve' '21 Jump Street' 'Velociraptor']
#
# Movie: A Hologram for the King
# Top 5 recommended Movies: ['Gasland' 'After Last Season' 'Andrew Dice Clay: Indestructible'
#  'Cosmopolis' 'Syriana']
#
# Movie: Spaceballs
# Top 5 recommended Movies: ['Despicable Me' 'The Frontier' 'The Gamers' 'The Jungle Book'
#  'The Lord of the Rings: The Two Towers']
#
# Movie: Sunshine Cleaning
# Top 5 recommended Movies: ['Cougars, Inc.' 'Bambi II' 'Rabbit Hole' 'Hard Sell' 'The Babadook']
#
# Movie: Duplicity
# Top 5 recommended Movies: ['Miss Nobody' 'A Prayer for Rain' 'Home Alone 3' 'Bounty Killer'
#  'Entrapment']
#
# Movie: Felon
# Top 5 recommended Movies: ['The Perfect Teacher' 'Death Race' 'Paradise Lost 3: Purgatory'
#  'The Irrefutable Truth About Demons' "Shoot 'Em Up"]
#
# Movie: Magnolia
# Top 5 recommended Movies: ['A Horse for Summer' 'Ten Inch Hero' 'Kinyarwanda' '360' 'Restrepo']
#
# Movie: It's Complicated
# Top 5 recommended Movies: ['To Save A Life' 'The Hearse' '27 Dresses'
#  'Peace, Love & Misunderstanding' 'Jane Eyre']
#
# Movie: The Void
# Top 5 recommended Movies: ['John Carter' 'The Last Exorcism' 'The Waiting Room' 'The Bucket List'
#  'Eragon']
#
# Movie: Shall We Dance?
# Top 5 recommended Movies: ['William Kunstler Disturbing the Universe' 'Kamikaze Girls'
#  'Teri Meri Kahaani' 'The Accidental Spy' 'Aarya']
#
# Movie: Head in the Clouds
# Top 5 recommended Movies: ['New York' '2 Alone in Paris' 'Ballerina' 'For Lovers Only' 'Hostel']
#
# Movie: The Bucket List
# Top 5 recommended Movies: ['Home' 'Never Let Me Go' 'The Void' 'Virtual Revolution'
#  "A Birder's Guide to Everything"]
#
# Movie: Tinker Bell
# Top 5 recommended Movies: ['Tinker Bell and the Lost Treasure' "McHale's Navy Joins the Air Force"
#  'One Direction: This Is Us' 'Evita'
#  'Barbie: Mariposa and The Fairy Princess']
#
# Movie: After.Life
# Top 5 recommended Movies: ['A Mighty Heart' 'The Squeeze' 'The Unknown Girl' 'Boogeyman 2'
#  'The Ward']
#
# Movie: Knocked Up
# Top 5 recommended Movies: ['Two Night Stand' 'Why Blame It on the Child?' 'Nearing Grace'
#  'The Crying Dead' 'Life']
#
# Movie: Tracers
# Top 5 recommended Movies: ['Premium Rush' 'Safe' 'The Wannabe' 'Sugar Hill' 'Prime Evil']
#
# Movie: Religulous
# Top 5 recommended Movies: ['Jim Jefferies: I Swear to God' 'Jewtopia'
#  'Black Sun: The Mythological Background of National Socialism'
#  'Mercury Plains' 'Of Gods and Men']
#
# Movie: Insidious: Chapter 2
# Top 5 recommended Movies: ['Viktor' 'Man Down' 'Colossal' 'Alone Yet Not Alone' 'Jane Eyre']
#
# Movie: The Dukes of Hazzard
# Top 5 recommended Movies: ['Hoovey' 'The Flim-Flam Man' 'I Am Number Four'
#  'Nanny McPhee and the Big Bang' 'Lawless']
#
# Movie: The Man from Nowhere
# Top 5 recommended Movies: ['The Gamers' 'Neighbor' 'Lock, Stock and Two Smoking Barrels'
#  'Hot Girls Wanted' 'Kite']
#
# Movie: Ronal the Barbarian
# Top 5 recommended Movies: ['Black Death' 'Kubo and the Two Strings' 'Dance of the Dead'
#  'Opposite Day' 'Adventures of Power']
#
# Movie: Faster
# Top 5 recommended Movies: ['Fare' 'Running Time' 'The Legend of Zorro' 'Senna' 'Colombiana']
#
# Movie: Two for the Money
# Top 5 recommended Movies: ['Prince of Persia: The Sands of Time' 'Head Games'
#  'The Mortal Instruments: City of Bones' 'Pony Excess'
#  'The Legend of Jimmy the Greek']
#
# Movie: Brick
# Top 5 recommended Movies: ['Inherent Vice' '21 Jump Street' 'Mamaboy' 'An Education' 'Dare']
#
# Movie: The Avengers
# Top 5 recommended Movies: ['Independence Day: Resurgence' 'Allegiant' 'Echelon Conspiracy'
#  'Wall Street: Money Never Sleeps' 'Avengers: Age of Ultron']
#
# Movie: The Circle
# Top 5 recommended Movies: ['Knowing' 'April Rain' 'Mass Effect: Paragon Lost' 'Erasing David'
#  'Spawn: The Recall']
